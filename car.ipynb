# %% [markdown]
# #  Importing libraries that are required

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mp

# %% [markdown]
# #  Reading data

# %%
car = pd.read_csv("D:\PROJECTS\Dataset\data.csv")

# %%
print("No of data points and columns : ",car.shape)
# Out:
# No of data points and columns :  (11914, 16)

# %%
print("Column names : " , car.columns)
# Out:
# Column names :  Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# #  changing columns names

# %%
car.columns=['Make', 'Model', 'Year', 'Engine Fuel Type', 'HP',
       'Cylinders', 'Type', 'DriveMode',
       'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
       'MPG_H', 'MPG_c', 'Popularity', 'price']

# %% [markdown]
# # Observing top 5 and bottom 5

# %%
car.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#      Type         DriveMode  Number of Doors  \
# 0  MANUAL  rear wheel drive              2.0
# 1  MANUAL  rear wheel drive              2.0
# 2  MANUAL  rear wheel drive              2.0
# 3  MANUAL  rear wheel drive              2.0
# 4  MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  MPG_H  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                     Luxury,Performance      Compact   Convertible     28
# ...

# %%
car.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type     HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)  300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)  300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)  300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)  300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded  221.0
#
#        Cylinders       Type          DriveMode  Number of Doors  \
# 11909        6.0  AUTOMATIC    all wheel drive              4.0
# 11910        6.0  AUTOMATIC    all wheel drive              4.0
# 11911        6.0  AUTOMATIC    all wheel drive              4.0
# 11912        6.0  AUTOMATIC    all wheel drive              4.0
# 11913        6.0  AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  MPG_H  MPG_c  \
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# ...

# %%
Makers=car['Make'].value_counts()
MP=car[['Make','price']]
print(MP)
# Out:
#           Make  price
# 0          BMW  46135
# 1          BMW  40650
# 2          BMW  36350
# 3          BMW  29450
# 4          BMW  34500
# ...        ...    ...
# 11909    Acura  46120
# 11910    Acura  56670
# 11911    Acura  50620
# 11912    Acura  50920
# 11913  Lincoln  28995
#
# [11914 rows x 2 columns]

# %% [markdown]
# # Info about the data frame(with data types of each feature)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Make              11914 non-null  object
#  1   Model             11914 non-null  object
#  2   Year              11914 non-null  int64
#  3   Engine Fuel Type  11911 non-null  object
#  4   HP                11845 non-null  float64
#  5   Cylinders         11884 non-null  float64
#  6   Type              11914 non-null  object
#  7   DriveMode         11914 non-null  object
#  8   Number of Doors   11908 non-null  float64
#  9   Market Category   8172 non-null   object
#  10  Vehicle Size      11914 non-null  object
#  11  Vehicle Style     11914 non-null  object
#  12  MPG_H             11914 non-null  int64
#  13  MPG_c             11914 non-null  int64
#  14  Popularity        11914 non-null  int64
#  15  price             11914 non-null  int64
# ...

# %% [markdown]
# # Staticstics of features

# %%
car.describe()
# Out:
#                Year           HP     Cylinders  Number of Doors         MPG_H  \
# count  11914.000000  11845.00000  11884.000000     11908.000000  11914.000000
# mean    2010.384338    249.38607      5.628829         3.436093     26.637485
# std        7.579740    109.19187      1.780559         0.881315      8.863001
# min     1990.000000     55.00000      0.000000         2.000000     12.000000
# 25%     2007.000000    170.00000      4.000000         2.000000     22.000000
# 50%     2015.000000    227.00000      6.000000         4.000000     26.000000
# 75%     2016.000000    300.00000      6.000000         4.000000     30.000000
# max     2017.000000   1001.00000     16.000000         4.000000    354.000000
#
#               MPG_c    Popularity         price
# count  11914.000000  11914.000000  1.191400e+04
# mean      19.733255   1554.911197  4.059474e+04
# std        8.987798   1441.855347  6.010910e+04
# min        7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# # Plots to eliminates unwanted features

# %%
for i in car.columns:
    if(i!='price'):
        car.plot(x=i,y='price',style='o')
        #car.plot(x=i,y='price')

# %%
for i in car.columns:
    if(i!='price'):
        car.plot(x=i,y='price')

# %% [markdown]
# **Removing some features based on above 2D plots**
# We can see every feature is compared with price, now we are removing
# **"Make,Model,Engine Fuel Type,Type,Market Category,Vehicle size,Vehicle style"**
# these features. It doesn't mean that they dont pay role in price variation but not significantly.

# %%
car=car.drop(['Make', 'Model', 'Engine Fuel Type','Type','Market Category', 'Vehicle Size', 'Vehicle Style'], axis=1)
car.head(5)
# Out:
#    Year     HP  Cylinders         DriveMode  Number of Doors  MPG_H  MPG_c  \
# 0  2011  335.0        6.0  rear wheel drive              2.0     26     19
# 1  2011  300.0        6.0  rear wheel drive              2.0     28     19
# 2  2011  300.0        6.0  rear wheel drive              2.0     28     20
# 3  2011  230.0        6.0  rear wheel drive              2.0     28     18
# 4  2011  230.0        6.0  rear wheel drive              2.0     28     18
#
#    Popularity  price
# 0        3916  46135
# 1        3916  40650
# 2        3916  36350
# 3        3916  29450
# 4        3916  34500

# %% [markdown]
# **Present Shape of DataFrame car**

# %%
car.shape
# Out:
# (11914, 9)

# %%
#Columns
car.columns
# Out:
# Index(['Year', 'HP', 'Cylinders', 'DriveMode', 'Number of Doors', 'MPG_H',
#        'MPG_c', 'Popularity', 'price'],
#       dtype='object')

# %% [markdown]
# # Duplicate rows deletion

# %%
car[car.duplicated()]
# Out:
#        Year     HP  Cylinders          DriveMode  Number of Doors  MPG_H  \
# 14     2013  230.0        6.0   rear wheel drive              2.0     28
# 18     1992  172.0        6.0  front wheel drive              4.0     24
# 20     1992  172.0        6.0  front wheel drive              4.0     24
# 24     1993  172.0        6.0  front wheel drive              4.0     24
# 25     1993  172.0        6.0  front wheel drive              4.0     24
# ...     ...    ...        ...                ...              ...    ...
# 11481  1998   95.0        4.0   four wheel drive              2.0     26
# 11603  2017  302.0        4.0    all wheel drive              4.0     29
# 11604  2017  240.0        4.0  front wheel drive              4.0     30
# 11708  2008  252.0        6.0    all wheel drive              4.0     22
# 11717  2008  252.0        6.0  front wheel drive              4.0     22
#
#        MPG_c  Popularity  price
# 14        19        3916  31500
# ...

# %% [markdown]
#  **Found total 908 rows which are duplicates**

# %%
car=car.drop_duplicates()
print("after removing duplicates num of rows and columns",car.shape)
# Out:
# after removing duplicates num of rows and columns (11006, 9)

# %% [markdown]
# # Now we need to remove null values

# %%
#checking for existance of null values
car.isnull().values.any()
# Out:
# True

# %%
#No of null values in entire dataframe
car.isnull().sum().sum()
# Out:
# 105

# %%
#droping null values from dataframe
print("Data frame shape before droping nulls",car.shape)
car=car.dropna()
print("Data frame shape after droping nulls",car.shape)
# Out:
# Data frame shape before droping nulls (11006, 9)
# Data frame shape after droping nulls (10907, 9)

# %% [markdown]
# # Removing the Outliers
# We can detect outliers using boxplots,Zscore,percentiles etc. But here we proceed with boxplots, if it cause difficulty in detection outliers then we move into other methods of finding outliers.

# %%
car.columns
# Out:
# Index(['Year', 'HP', 'Cylinders', 'DriveMode', 'Number of Doors', 'MPG_H',
#        'MPG_c', 'Popularity', 'price'],
#       dtype='object')

# %%
for i in car.columns:
    if (i !='DriveMode'):
        sns.boxplot(y=i,data=car)
        mp.pyplot.show()
    #sns.boxplot(y=car[i])
#sns.boxplot(y=i,data=car)

# %%
#sns.boxplot(y=car['price'],x=car['DriveMode'])

# %%
car.columns
# Out:
# Index(['Year', 'HP', 'Cylinders', 'DriveMode', 'Number of Doors', 'MPG_H',
#        'MPG_c', 'Popularity', 'price'],
#       dtype='object')

# %% [markdown]
# **From the above boxplots its**

# %%
for i in car.columns:
    if (i!='DriveMode'):
        Q1 = car[i].quantile(0.25)
        Q3 = car[i].quantile(0.75)
        IQR = Q3 - Q1
        #car = car[~((car[i] < (Q1 - 1.5 * IQR)) |(car[i] > (Q3 + 1.5 * IQR)))][i]
        filters = (car[i] >= Q1 - 1.5 * IQR) & (car[i] <= Q3 + 1.5 *IQR)
        car=car.loc[filters]

# %%
print("after removal of outliers from car dataFrame shape of dataframe : ",car.shape)
# Out:
# after removal of outliers from car dataFrame shape of dataframe :  (8450, 9)

# %% [markdown]
# **Now ploting the boxplots inorder to check wheather outliers are removed or not.**

# %%
for i in car.columns:
    if (i !='DriveMode'):
        sns.boxplot(y=i,data=car)
        mp.pyplot.show()
    #sns.boxplot(y=car[i])
#sns.boxplot(y=i,data=car)

# %% [markdown]
# # Top 10 represented car makers with there mean price

# %%
#before eliminating make column we saved that in Makers as a series object
Makers.head(10).plot(kind="bar")

# %%
MeanAmount = MP[['Make','price']].loc[(MP['Make'] == 'Chevrolet')|
               (MP['Make'] == 'Ford')|
               (MP['Make'] == 'Volkswagen')|
               (MP['Make'] == 'Toyota')|
               (MP['Make'] == 'Dodge')|
               (MP['Make'] == 'Nissan')|
               (MP['Make'] == 'GMC')|
               (MP['Make'] == 'Honda')|
               (MP['Make'] == 'Mazda')|(MP['Make']=='Cadillac')].groupby('Make').mean()
print(round(MeanAmount['price'],2))
round(MeanAmount['price'],2).plot(kind="bar")
#price rounding off to 2 decimals
# Out:
# Make
# Cadillac      56231.32
# Chevrolet     28350.39
# Dodge         22390.06
# Ford          27399.27
# GMC           30493.30
# Honda         26674.34
# Mazda         20039.38
# Nissan        28583.43
# Toyota        29030.02
# Volkswagen    28102.38
# Name: price, dtype: float64

# %% [markdown]
# # Correlation Matrix

# %%
car.corr()
# Out:
#                      Year        HP  Cylinders  Number of Doors     MPG_H  \
# Year             1.000000  0.318256  -0.112402         0.244520  0.375230
# HP               0.318256  1.000000   0.735256         0.040560 -0.457774
# Cylinders       -0.112402  0.735256   1.000000         0.019035 -0.693411
# Number of Doors  0.244520  0.040560   0.019035         1.000000  0.011900
# MPG_H            0.375230 -0.457774  -0.693411         0.011900  1.000000
# MPG_c            0.337014 -0.557828  -0.747326         0.027839  0.937943
# Popularity       0.197737  0.086682   0.008734        -0.075513  0.097126
# price            0.588409  0.740093   0.384355         0.135580 -0.120640
#
#                     MPG_c  Popularity     price
# Year             0.337014    0.197737  0.588409
# HP              -0.557828    0.086682  0.740093
# Cylinders       -0.747326    0.008734  0.384355
# Number of Doors  0.027839   -0.075513  0.135580
# MPG_H            0.937943    0.097126 -0.120640
# ...

# %% [markdown]
# # conclusions drawn from correlation matrix
#
# 1) HP and Cylinders are +vely correlated.<br>
# 2) HP and Price are +vely correlated.<br>
# 3) Cylinders and MPG_H are -vely correlated.<br>
# 4) Cylinders and MPG_c are -vely correlated.<br>
# 5) MPG_H and MPG_c are +vely correlated.<br>

# %% [markdown]
# # Exploratory Data analysis

# %%
mp.pyplot.figure(figsize=(20,8))
car.plot.bar(x="Year", y="price")

# %%
car[['Year','price']].plot()
mp.pyplot.show()

# %%
#from above its not clear so we use bars
for i in car.columns:
    if(i!='price' and i!='HP'):
        mp.pyplot.figure(figsize=(14,8))
        sns.barplot(car[i],car['price'])
        mp.pyplot.show()

# %% [markdown]
# <h3>Conclusions:</h3>
# 1) From 2001 price got jumped from below 5k to above 20k<br>
# 2) Less price for 3 cylinders car and almost same cost for 4,5 where as 6,7 are more price than all of them<br>
# 3) Front wheel drive mode is less priced among others<br>
# 4) Cars with 2,4 doors are most priced than 3 doored<br>
# 5) Almost same priced for every MPG_H and MPG_C<br>
# 6) Popularity not effecting the price effectively<br>
